# %% [markdown]
# # Back-propagation
#
# ## Learning Objectives
# - Demonstrate a conceptual understanding of back-propagation by explaining back-propagation in your own words
# - Demonstrate a mathematical understanding of back-propagation by explaining back-propagation in your own words

# %% [markdown]
# In the guided project I gave a quick explanation of back-propagation at the beginning of the Sprint 2 Module 3 lesson, which you can watch here.

# %%
from IPython.lib.display import YouTubeVideo

# %%
YouTubeVideo('HO4qcy12MkM',  width=1000, height=500)

# %% [markdown]
# The nice about basing our understanding of back-propagation on the calculus is that **we can easily read off the concept of back-propagation** by looking at the following image.
#
# The not-so-nice thing about basing our understanding of back-propagation on the calculus is that, if we are not comfortable with calculus, then **we can not easily read off the concept of back-propagation** by looking at the following image.
#
#
# ![](https://miro.medium.com/max/3272/1*niUm-3-CXV4DMAg916a9Wg.png)
#
# If you find yourself in the second camp, then don't worry because I have some resources for you!
#
# The goal of this notebook is that if you watch both of the following videos (and assuming that you read through the Intro to Calculus notebook I shared) you will be able to explain the above image at the end of this notebook!

# %% [markdown]
# -----
#
# ## Video Resources
#
# This section contains two excellent videos that explain back-propagation. It is HIGHLY recommended that you watch both of them.
#
# ### Watch this video on the concept of Backpropagation
#
# This video will help you develop a conceptual understanding of back-propagation.

# %%
YouTubeVideo('Ilg3gGewQ5U',  width=1000, height=500)

# %% [markdown]
# ### Watch this video on the Calculus of Backpropagation
#
# This video will help you develop a mathematical understanding of back-propagation.
#
# If this second videos still seems like a insurmountable technical mountain with mathematical jargon. That's ok, then focus on the previous videos.
#
# A conceptual understanding of back-propagation is important.
#
# A mathematical understanding of back-propagation is a nice-to-have.

# %%
YouTubeVideo('tIeHLnjs5U8',  width=1000, height=500)

# %% [markdown]
# ------
#
# ## Written Resources
#
# Maybe the videos didn't quite make sense to you, maybe the videos did make sense to you but you're hungry for an alternative explanation in a different format. Then I encourage you to read through at least 1 of the 3 articles that I've curated for you. Yes, you -- the people.
#
# [**A step-by-step back-propagation example**](https://mattmazur.com/2015/03/17/a-step-by-step-backpropagation-example/)
#
# - explains back-propagation by working through a simple example and keeping the math as simple as possible as well.
#
#
# [**Back-propagation explained using matrix multiplication**](https://medium.com/@14prakash/back-propagation-is-very-simple-who-made-it-complicated-97b794c97e5c)
#
# - underneath the API there are a lot of matrix multiplication calculations happening. If you'd like to understand Back-propagation from this perspective, check out this article.
#
# [**Gradient Descent and Back-propagation**](https://towardsdatascience.com/part-2-gradient-descent-and-backpropagation-bf90932c066a)
#
# - explains back-propagation in the context of Gradient Descent
# - presents the math very simply and with great attention to detail
# - my favorite of the 3 articles

# %% [markdown]
# ----

# %% [markdown]
# ## Check for Understanding
#
# ![](https://miro.medium.com/max/3272/1*niUm-3-CXV4DMAg916a9Wg.png)
#
# You have now watched both videos and read through at least 1 of the 3 articles. I tip my hat to you good sir, fair lady, and stuffed dogs named Giro.
#
# Now we test your reading/listening comprehension with questions.

# %% [markdown]
# **Question 1:**
#
# In your own words, explain the concept of back-propagation.

# %% [markdown]
# **Answer 1:**
#
# `Write your answer here.`

# %% [markdown]
# **Questions 2:**
#
# In your own words, explain the above image at the level of the partial derivatives. That is, explain what each partial derivative means and how they all fit into back-propagation.

# %% [markdown]
# **Answer 2:**
#
# `Write your answer here.`
